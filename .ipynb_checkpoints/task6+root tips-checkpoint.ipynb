# %%
import tensorflow.keras.backend as K
import tensorflow as tf
from tensorflow.keras import backend as K
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from patchify import patchify, unpatchify
from tensorflow.keras import backend as K
from skimage.measure import label

def f1(y_true, y_pred, threshold=0.3):
    y_pred = tf.cast(y_pred > threshold, tf.float32)
    TP = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
    Positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
    Pred_Positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
    precision = TP / (Pred_Positives + tf.keras.backend.epsilon())
    recall = TP / (Positives + tf.keras.backend.epsilon())
    return 2 * ((precision * recall) / (precision + recall + tf.keras.backend.epsilon()))
    
@tf.keras.utils.register_keras_serializable()
def f1_metric(y_true, y_pred):
    return f1(y_true, y_pred, threshold=0.3)


def weighted_binary_crossentropy(y_true, y_pred):
    """
    Weighted binary cross-entropy to address class imbalance.
    """
    # Define weights for foreground (root, shoot, seed) and background
    weight_foreground = 10.0
    weight_background = 1.0

    # Compute weighted binary cross-entropy
    y_true = K.flatten(y_true)
    y_pred = K.flatten(y_pred)
    weights = tf.where(y_true == 1, weight_foreground, weight_background)
    loss = K.binary_crossentropy(y_true, y_pred)
    weighted_loss = loss * weights
    return K.mean(weighted_loss)
def dice_loss(y_true, y_pred):
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred)
    dice = (2. * intersection + 1e-7) / (union + 1e-7)
    return 1 - dice

@tf.keras.utils.register_keras_serializable()
def combined_loss(y_true, y_pred):
    return 0.5 * dice_loss(y_true, y_pred) + 0.5 * weighted_binary_crossentropy(y_true, y_pred)
# Out:
# 2025-01-08 15:45:54.056777: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-08 15:45:54.056838: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-08 15:45:54.058479: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-08 15:45:54.067980: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import logging

# Logging configuration
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[logging.FileHandler("pipeline_log.txt"), logging.StreamHandler()],
)

def preprocess_image(image_path):
    """Load and preprocess the input image."""
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        raise ValueError(f"Failed to load image: {image_path}")
    return image

def extract_petri_dish(image):
    """Extract the largest contour assumed to be the Petri dish."""
    _, thresholded = cv2.threshold(image, 57, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresholded, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if not contours:
        logging.warning("No contours detected for Petri dish.")
        return image, np.ones_like(image)

    largest_contour = max(contours, key=cv2.contourArea)
    x, y, w, h = cv2.boundingRect(largest_contour)
    cropped_image = image[y:y+h, x:x+w]
    return cropped_image

def predict_root_mask(image, model, patch_size=128, stride=64):
    """Predict root mask using a patch-based model."""
    h, w = image.shape
    patches = []
    positions = []
    for y in range(0, h - patch_size + 1, stride):
        for x in range(0, w - patch_size + 1, stride):
            patch = image[y:y+patch_size, x:x+patch_size]
            patch_rgb = np.stack([patch]*3, axis=-1)
            patches.append(patch_rgb)
            positions.append((y, x))

    patches = np.array(patches) / 255.0
    predictions = model.predict(patches, verbose=0)

    reconstructed = np.zeros((h, w), dtype=np.float32)
    counts = np.zeros((h, w), dtype=np.float32)
    for pred, (y, x) in zip(predictions, positions):
        pred = pred[..., 0]
        reconstructed[y:y+patch_size, x:x+patch_size] += pred
        counts[y:y+patch_size, x:x+patch_size] += 1
    return (reconstructed / np.maximum(counts, 1) > 0.3).astype(np.uint8)

def connect_roots(mask):
    """Dilate the mask to connect fragmented roots."""
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (2, 2))
    return cv2.dilate(mask, kernel, iterations=27)

def filter_and_select_largest_objects(mask, min_area=500, max_objects=5):
    """Filter and retain the largest root components."""
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(mask, connectivity=8)
    valid_objects = [(i, stats[i, cv2.CC_STAT_AREA]) for i in range(1, num_labels) if stats[i, cv2.CC_STAT_AREA] >= min_area]
    largest_objects = sorted(valid_objects, key=lambda x: x[1], reverse=True)[:max_objects]

    filtered_mask = np.zeros_like(mask, dtype=np.uint8)
    for obj_id, _ in largest_objects:
        filtered_mask[labels == obj_id] = 255
    return filtered_mask, largest_objects

def measure_bounding_boxes(filtered_mask):
    """Measure roots with bounding boxes."""
    contours, _ = cv2.findContours(filtered_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    bounding_boxes = [cv2.boundingRect(contour) for contour in contours]
    bounding_boxes = sorted(bounding_boxes, key=lambda b: b[0])
    return bounding_boxes

def find_lowest_point(mask, bounding_box):
    """Find the lowest point in a bounding box."""
    x, y, w, h = bounding_box
    roi = mask[y:y+h, x:x+w]
    coordinates = np.column_stack(np.where(roi > 0))
    if len(coordinates) == 0:
        return None
    lowest_local = coordinates[np.argmax(coordinates[:, 0])]
    return lowest_local + [y, x]

def convert_to_mm(pixel_coords, image_shape, plate_size_mm=150):
    """Convert pixel coordinates to mm-space."""
    h, w = image_shape
    conversion_factor_x = plate_size_mm / w
    conversion_factor_y = plate_size_mm / h
    return np.array([pixel_coords[1] * conversion_factor_x, pixel_coords[0] * conversion_factor_y])

# Directory containing images
input_dir = "kaggle_test"
model_path = "232430_unet_model_128px_v7md.keras"
plate_position_robot = np.array([0.10775, 0.088 - 0.026, 0.057])  # Adjust based on your setup

# Load the model
model = tf.keras.models.load_model(model_path)

# Process all images in the directory
all_root_tip_coords = {}

for image_name in sorted(os.listdir(input_dir)):
    if not image_name.endswith((".png", ".jpg", ".jpeg")):
        continue

    image_path = os.path.join(input_dir, image_name)
    logging.info(f"Processing image: {image_name}")

    try:
        # Process the image and extract root tip coordinates
        image = preprocess_image(image_path)
        petri_dish = extract_petri_dish(image)
        predicted_mask = predict_root_mask(petri_dish, model)
        connected_mask = connect_roots(predicted_mask)
        filtered_mask, _ = filter_and_select_largest_objects(connected_mask, min_area=500, max_objects=5)
        bounding_boxes = measure_bounding_boxes(filtered_mask)

        root_tip_coords = []
        for box in bounding_boxes:
            point = find_lowest_point(filtered_mask, box)
            if point is not None:
                mm_coords = convert_to_mm(point, petri_dish.shape)
                robot_coords = np.append(mm_coords, 0) + plate_position_robot
                root_tip_coords.append(robot_coords)

        all_root_tip_coords[image_name] = root_tip_coords
        logging.info(f"Extracted Root Tip Coordinates for {image_name}: {root_tip_coords}")

    except Exception as e:
        logging.error(f"Error processing image {image_name}: {e}")

# Expose all_root_tip_coords for import
def get_root_tip_coords():
    return all_root_tip_coords

# Log all extracted root tip coordinates
logging.info("All Extracted Root Tip Coordinates:")
for img_name, coords in all_root_tip_coords.items():
    logging.info(f"{img_name}: {coords}")
# Out:
# 2025-01-08 15:45:59.733824: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2025-01-08 15:45:59.772795: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15068 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:c1:00.0, compute capability: 8.6
# INFO: Processing image: test_image_1.png
# 2025-01-08 15:46:07.752486: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8906
# INFO: Extracted Root Tip Coordinates for test_image_1.png: [array([ 6.89359458, 43.1754469 ,  0.057     ]), array([1.65251159e+01, 6.26390207e+01, 5.70000000e-02]), array([23.2015114 , 54.59262704,  0.057     ]), array([7.61201542e+01, 3.94784552e+01, 5.70000000e-02]), array([1.25864773e+02, 4.50239427e+01, 5.70000000e-02])]
# INFO: Processing image: test_image
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    handlers=[logging.StreamHandler(), logging.FileHandler(log_file)],
)

logging.info("Starting Optimized PID Controller Test with OT2Env")

# Initialize the OT2 environment
env = OT2Env()

# Initialize PID parameters
pid_x = PIDController(Kp=14, Ki=2.05, Kd=2, dt=1.5, integral_limit=5.0)
pid_y = PIDController(Kp=14, Ki=2.05, Kd=2, dt=1.5, integral_limit=5.0)
pid_z = PIDController(Kp=14, Ki=2.05, Kd=1.5, dt=1.5, integral_limit=1.0)

# Modify the dynamic gain adjustment logic
def adjust_pid_gains(error):
    if error > 0.5:  # Large error
        pid_x.Kp, pid_x.Ki, pid_x.Kd = 17, 2.8, 4
        pid_y.Kp, pid_y.Ki, pid_y.Kd = 8, 2.7, 4
        pid_z.Kp, pid_z.Ki, pid_z.Kd = 6, 1.1, 3.5
    elif 0.2 < error <= 0.5:  # Medium error
        pid_x.Kp, pid_x.Ki, pid_x.Kd = 12, 1.58, 3
        pid_y.Kp, pid_y.Ki, pid_y.Kd = 12, 1.58, 3
        pid_z.Kp, pid_z.Ki, pid_z.Kd = 12, 1.58, 2.6
    else:  # Small error
        pid_x.Kp, pid_x.Ki, pid_x.Kd = 7, 1.05, 2.3
        pid_y.Kp, pid_y.Ki, pid_y.Kd = 7, 1.05, 2.3
        pid_z.Kp, pid_z.Ki, pid_z.Kd = 7, 1.05, 1.2

# Get coordinates from the pipeline
root_tip_coords = all_root_tip_coords

if not root_tip_coords:
    logging.error("No root tip coordinates provided.")
    print("No root tip coordinates found. Exiting...")
    exit()

# Iterate over each image and its root tip coordinates
for image_name, coordinates in root_tip_coords.items():
    logging.info(f"Processing root tips for {image_name}")
    print(f"Processing {image_name}...")

    for idx, target_position in enumerate(coordinates):
        logging.info(f"Root Tip {idx + 1}: Target Position: {target_position}")
        print(f"Root Tip {idx + 1}: Target Position: {target_position}")

        try:
            observation, info = env.reset()
            print(f"Environment reset. Initial observation: {observation}")
        except Exception as e:
            logging.error(f"Environment reset failed: {e}")
            print(f"Failed to reset environment for {image_name}, Root Tip {idx + 1}.")
            continue

        # Initialize loop variables
        terminated = False
        epoch = 0
        recent_errors = []

        # Simulation loop
        while not terminated and epoch < 200:
            epoch += 1

            # Current pipette position
            current_position = observation[:3]

            # Compute individual axis errors
            error_x = abs(target_position[0] - current_position[0])
            error_y = abs(target_position[1] - current_position[1])
            error_z = abs(target_position[2] - current_position[2])
            error = np.linalg.norm(target_position - current_position)

            # Log errors and coordinates
            logging.info(f"Epoch: {epoch}")
            logging.info(f"Current Position: X={current_position[0]:.4f}, Y={current_position[1]:.4f}, Z={current_position[2]:.4f}")
            logging.info(f"Errors: X={error_x:.4f}, Y={error_y:.4f}, Z={error_z:.4f}")
            logging.info(f"Euclidean Error: {error:.4f}")
            print(f"Epoch {epoch}: Euclidean Error = {error:.4f}")

            # Success criterion
            if error <= 0.005:
                logging.info(f"Root Tip {idx + 1}: Target reached successfully in {epoch} epochs. Final Error: {error:.4f}")
                print(f"Root Tip {idx + 1} reached in {epoch} epochs with final error {error:.4f}")
                break

            # Dynamically adjust PID gains based on error magnitude
            adjust_pid_gains(error)

            # Compute control actions with action saturation
            control_x = np.clip(pid_x.compute(current_position[0]), -1, 1)
            control_y = np.clip(pid_y.compute(current_position[1]), -1, 1)
            control_z = np.clip(pid_z.compute(current_position[2]), -1, 1)
            action = np.array([control_x, control_y, control_z])

            # Take a step in the environment
            try:
                observation, _, terminated, truncated, _ = env.step(action)
            except Exception as e:
                logging.error(f"Environment step failed: {e}")
                print(f"Failed to take a step for {image_name}, Root Tip {idx + 1}.")
                break

            # Track recent errors for early termination
            recent_errors.append(error)
            if len(recent_errors) > 20:
                recent_errors.pop(0)
                avg_error_change = abs(recent_errors[-1] - recent_errors[0]) / 20
                if avg_error_change < 0.0005:
                    logging.info(f"Terminating early due to negligible error change after {epoch} epochs.")
                    print(f"Early termination at epoch {epoch} due to negligible error change.")
                    break

            # Handle truncation
            if truncated:
                logging.warning("Environment truncated. Resetting...")
                observation, info = env.reset()

        # Log final result for this root tip
        if error > 0.005:
            logging.warning(f"Root Tip {idx + 1}: Failed to reach target within 200 epochs.")
            print(f"Root Tip {idx + 1} failed to reach target within 200 epochs.")

logging.info("PID Controller Test Complete.")
print("PID Controller Test Complete. Check the log file for details.")
# Out:
# INFO: Starting Optimized PID Controller Test with OT2Env
# INFO: Processing root tips for test_image_1.png
# INFO: Root Tip 1: Target Position: [ 6.89359458 43.1754469   0.057     ]
# INFO: Epoch: 1
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=6.8206, Y=43.0859, Z=0.0625
# INFO: Euclidean Error: 43.6225
# INFO: Epoch: 2
# INFO: Current Position: X=0.0731, Y=0.0893, Z=0.1199
# INFO: Errors: X=6.8205, Y=43.0861, Z=0.0629
# INFO: Euclidean Error: 43.6227
# INFO: Epoch: 3
# INFO: Current Position: X=0.0765, Y=0.0902, Z=0.1200
# INFO: Errors: X=6.8171, Y=43.0852, Z=0.0630
# INFO: Euclidean Error: 43.6213
# INFO: Epoch: 4
# INFO: Current Position: X=0.0789, Y=0.0904, Z=0.1199
# INFO: Errors: X=6.8147, Y=43.0850, Z=0.0629
# INFO: Euclidean Error: 43.6207
# INFO: Epoch: 5
# INFO: Current Position: X=0.0823, Y=0.0905, Z=0.1192
# INFO: Errors: X=6.8113, Y=43.0849, Z=0.0622
# INFO: Euclidean Error: 43.6201
# INFO: Epoch: 6
# INFO: Current Position: X=0.0848, Y=0.0905, Z=0.1188
# INFO: Errors: X=6.8088, Y=43.0849, Z=0.0618
# INFO: Euclidean Error: 43.6197
# INFO: Epoch: 7
# INFO: Current Position: X=0.0868, Y=0.0904, Z=0.1183
# INFO: Errors: X=6.8068, Y=43.0850, Z=0.0613
# INFO: Euclidean Error: 43.6195
# INFO: Epoch: 8
# INFO: Current Position: X=0.0887, Y=0.0907, Z=0.1180
# INFO: Errors: X=6.8049, Y=43.0847, Z=0.0610
# INFO: Euclidean Error: 43.6189
# INFO: Epoch: 9
# INFO: Current Position: X=0.0898, Y=0.0906, Z=0.1174
# INFO: Errors: X=6.8038, Y=43.0848, Z=0.0604
# INFO: Euclidean Error: 43.6188
# INFO: Epoch: 10
# INFO: Current Position: X=0.0906, Y=0.0908, Z=0.1169
# INFO: Errors: X=6.8030, Y=43.0846, Z=0.0599
# INFO: Euclidean Error: 43.6185
# INFO: Epoch: 11
# INFO: Current Position: X=0.0909, Y=0.0912, Z=0.1163
# INFO: Errors: X=6.8027, Y=43.0842, Z=0.0593
# INFO: Euclidean Error: 43.6180
# INFO: Epoch: 12
# INFO: Current Position: X=0.0912, Y=0.0915, Z=0.1158
# INFO: Errors: X=6.8024, Y=43.0839, Z=0.0588
# INFO: Euclidean Error: 43.6177
# INFO: Epoch: 13
# INFO: Current Position: X=0.0916, Y=0.0922, Z=0.1152
# INFO: Errors: X=6.8020, Y=43.0832, Z=0.0582
# INFO: Euclidean Error: 43.6169
# INFO: Epoch: 14
# INFO: Current Position: X=0.0924, Y=0.0929, Z=0.1149
# INFO: Errors: X=6.8012, Y=43.0825, Z=0.0579
# INFO: Euclidean Error: 43.6161
# INFO: Epoch: 15
# Processing test_image_1.png...
# Root Tip 1: Target Position: [ 6.89359458 43.1754469   0.057     ]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195     -0.2697062   0.06910623  0.10274583]
# Epoch 1: Euclidean Error = 43.6225
# Epoch 2: Euclidean Error = 43.6227
# Epoch 3: Euclidean Error = 43.6213
# Epoch 4: Euclidean Error = 43.6207
# Epoch 5: Euclidean Error = 43.6201
# Epoch 6: Euclidean Error = 43.6197
# Epoch 7: Euclidean Error = 43.6195
# Epoch 8: Euclidean Error = 43.6189
# Epoch 9: Euclidean Error = 43.6188
# Epoch 10: Euclidean Error = 43.6185
# Epoch 11: Euclidean Error = 43.6180
# Epoch 12: Euclidean Error = 43.6177
# Epoch 13: Euclidean Error = 43.6169
# Epoch 14: Euclidean Error = 43.6161
# INFO: Current Position: X=0.0935, Y=0.0935, Z=0.1145
# INFO: Errors: X=6.8001, Y=43.0819, Z=0.0575
# INFO: Euclidean Error: 43.6153
# INFO: Epoch: 16
# INFO: Current Position: X=0.0939, Y=0.0937, Z=0.1145
# INFO: Errors: X=6.7997, Y=43.0817, Z=0.0575
# INFO: Euclidean Error: 43.6151
# INFO: Epoch: 17
# INFO: Current Position: X=0.0948, Y=0.0942, Z=0.1142
# INFO: Errors: X=6.7988, Y=43.0812, Z=0.0572
# INFO: Euclidean Error: 43.6145
# INFO: Epoch: 18
# INFO: Current Position: X=0.0949, Y=0.0942, Z=0.1138
# INFO: Errors: X=6.7987, Y=43.0812, Z=0.0568
# INFO: Euclidean Error: 43.6144
# INFO: Epoch: 19
# INFO: Current Position: X=0.0950, Y=0.0942, Z=0.1136
# INFO: Errors: X=6.7986, Y=43.0812, Z=0.0566
# INFO: Euclidean Error: 43.6144
# INFO: Epoch: 20
# INFO: Current Position: X=0.0953, Y=0.0945, Z=0.1130
# INFO: Errors: X=6.7983, Y=43.0809, Z=0.0560
# INFO: Euclidean Error: 43.6141
# INFO: Epoch: 21
# INFO: Current Position: X=0.0955, Y=0.0950, Z=0.1133
# INFO: Errors: X=6.7981, Y=43.0804, Z=0.0563
# INFO: Euclidean Error: 43.6136
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 1: Failed to reach target within 200 epochs.
# INFO: Root Tip 2: Target Position: [1.65251159e+01 6.26390207e+01 5.70000000e-02]
# INFO: Epoch: 1
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=16.4521, Y=62.5495, Z=0.0625
# INFO: Euclidean Error: 64.6770
# INFO: Epoch: 2
# INFO: Current Position: X=0.0735, Y=0.0890, Z=0.1195
# INFO: Errors: X=16.4516, Y=62.5500, Z=0.0625
# INFO: Euclidean Error: 64.6774
# INFO: Epoch: 3
# INFO: Current Position: X=0.0744, Y=0.0887, Z=0.1196
# INFO: Errors: X=16.4507, Y=62.5503, Z=0.0626
# INFO: Euclidean Error: 64.6775
# INFO: Epoch: 4
# INFO: Current Position: X=0.0746, Y=0.0889, Z=0.1196
# INFO: Errors: X=16.4505, Y=62.5501, Z=0.0626
# INFO: Euclidean Error: 64.6772
# INFO: Epoch: 5
# INFO: Current Position: X=0.0784, Y=0.0889, Z=0.1196
# INFO: Errors: X=16.4467, Y=62.5501, Z=0.0626
# INFO: Euclidean Error: 64.6762
# INFO: Epoch: 6
# INFO: Current Position: X=0.0809, Y=0.0890, Z=0.1195
# INFO: Errors: X=16.4442, Y=62.5500, Z=0.0625
# INFO: Euclidean Error: 64.6755
# INFO: Epoch: 7
# INFO: Current Position: X=0.0846, Y=0.0890, Z=0.1195
# INFO: Errors: X=16.4405, Y=62.5500, Z=0.0625
# INFO: Euclidean Error: 64.6746
# INFO: Epoch: 8
# INFO: Current Position: X=0.0870, Y=0.0889, Z=0.1195
# INFO: Errors: X=16.4381, Y=62.5501, Z=0.0625
# INFO: Euclidean Error: 64.6741
# INFO: Epoch: 9
# Epoch 15: Euclidean Error = 43.6153
# Epoch 16: Euclidean Error = 43.6151
# Epoch 17: Euclidean Error = 43.6145
# Epoch 18: Euclidean Error = 43.6144
# Epoch 19: Euclidean Error = 43.6144
# Epoch 20: Euclidean Error = 43.6141
# Epoch 21: Euclidean Error = 43.6136
# Early termination at epoch 21 due to negligible error change.
# Root Tip 1 failed to reach target within 200 epochs.
# Root Tip 2: Target Position: [1.65251159e+01 6.26390207e+01 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195     -0.11595756  0.12228294 -0.02421714]
# Epoch 1: Euclidean Error = 64.6770
# Epoch 2: Euclidean Error = 64.6774
# Epoch 3: Euclidean Error = 64.6775
# Epoch 4: Euclidean Error = 64.6772
# Epoch 5: Euclidean Error = 64.6762
# Epoch 6: Euclidean Error = 64.6755
# Epoch 7: Euclidean Error = 64.6746
# Epoch 8: Euclidean Error = 64.6741
# INFO: Current Position: X=0.0888, Y=0.0885, Z=0.1194
# INFO: Errors: X=16.4363, Y=62.5505, Z=0.0624
# INFO: Euclidean Error: 64.6740
# INFO: Epoch: 10
# INFO: Current Position: X=0.0895, Y=0.0882, Z=0.1193
# INFO: Errors: X=16.4356, Y=62.5508, Z=0.0623
# INFO: Euclidean Error: 64.6741
# INFO: Epoch: 11
# INFO: Current Position: X=0.0903, Y=0.0877, Z=0.1192
# INFO: Errors: X=16.4348, Y=62.5513, Z=0.0622
# INFO: Euclidean Error: 64.6744
# INFO: Epoch: 12
# INFO: Current Position: X=0.0911, Y=0.0878, Z=0.1190
# INFO: Errors: X=16.4340, Y=62.5512, Z=0.0620
# INFO: Euclidean Error: 64.6741
# INFO: Epoch: 13
# INFO: Current Position: X=0.0912, Y=0.0879, Z=0.1190
# INFO: Errors: X=16.4339, Y=62.5511, Z=0.0620
# INFO: Euclidean Error: 64.6740
# INFO: Epoch: 14
# INFO: Current Position: X=0.0923, Y=0.0878, Z=0.1189
# INFO: Errors: X=16.4328, Y=62.5512, Z=0.0619
# INFO: Euclidean Error: 64.6738
# INFO: Epoch: 15
# INFO: Current Position: X=0.0920, Y=0.0874, Z=0.1190
# INFO: Errors: X=16.4331, Y=62.5516, Z=0.0620
# INFO: Euclidean Error: 64.6742
# INFO: Epoch: 16
# INFO: Current Position: X=0.0912, Y=0.0870, Z=0.1190
# INFO: Errors: X=16.4339, Y=62.5520, Z=0.0620
# INFO: Euclidean Error: 64.6748
# INFO: Epoch: 17
# INFO: Current Position: X=0.0908, Y=0.0868, Z=0.1190
# INFO: Errors: X=16.4343, Y=62.5522, Z=0.0620
# INFO: Euclidean Error: 64.6751
# INFO: Epoch: 18
# INFO: Current Position: X=0.0906, Y=0.0864, Z=0.1190
# INFO: Errors: X=16.4345, Y=62.5526, Z=0.0620
# INFO: Euclidean Error: 64.6756
# INFO: Epoch: 19
# INFO: Current Position: X=0.0907, Y=0.0860, Z=0.1190
# INFO: Errors: X=16.4344, Y=62.5530, Z=0.0620
# INFO: Euclidean Error: 64.6759
# INFO: Epoch: 20
# INFO: Current Position: X=0.0910, Y=0.0857, Z=0.1190
# INFO: Errors: X=16.4341, Y=62.5533, Z=0.0620
# INFO: Euclidean Error: 64.6761
# INFO: Epoch: 21
# INFO: Current Position: X=0.0910, Y=0.0854, Z=0.1190
# INFO: Errors: X=16.4341, Y=62.5536, Z=0.0620
# INFO: Euclidean Error: 64.6764
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 2: Failed to reach target within 200 epochs.
# INFO: Root Tip 3: Target Position: [23.2015114  54.59262704  0.057     ]
# INFO: Epoch: 1
# Epoch 9: Euclidean Error = 64.6740
# Epoch 10: Euclidean Error = 64.6741
# Epoch 11: Euclidean Error = 64.6744
# Epoch 12: Euclidean Error = 64.6741
# Epoch 13: Euclidean Error = 64.6740
# Epoch 14: Euclidean Error = 64.6738
# Epoch 15: Euclidean Error = 64.6742
# Epoch 16: Euclidean Error = 64.6748
# Epoch 17: Euclidean Error = 64.6751
# Epoch 18: Euclidean Error = 64.6756
# Epoch 19: Euclidean Error = 64.6759
# Epoch 20: Euclidean Error = 64.6761
# Epoch 21: Euclidean Error = 64.6764
# Early termination at epoch 21 due to negligible error change.
# Root Tip 2 failed to reach target within 200 epochs.
# Root Tip 3: Target Position: [23.2015114  54.59262704  0.057     ]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195     -0.11393303  0.05921469 -0.01421917]
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=23.1285, Y=54.5031, Z=0.0625
# INFO: Euclidean Error: 59.2075
# INFO: Epoch: 2
# INFO: Current Position: X=0.0747, Y=0.0888, Z=0.1194
# INFO: Errors: X=23.1268, Y=54.5038, Z=0.0624
# INFO: Euclidean Error: 59.2074
# INFO: Epoch: 3
# INFO: Current Position: X=0.0762, Y=0.0879, Z=0.1194
# INFO: Errors: X=23.1253, Y=54.5047, Z=0.0624
# INFO: Euclidean Error: 59.2077
# INFO: Epoch: 4
# INFO: Current Position: X=0.0774, Y=0.0873, Z=0.1192
# INFO: Errors: X=23.1241, Y=54.5053, Z=0.0622
# INFO: Epoch: 12
# INFO: Current Position: X=0.0824, Y=0.0874, Z=0.1186
# INFO: Errors: X=76.0378, Y=39.3911, Z=0.0616
# INFO: Euclidean Error: 85.6353
# Epoch 18: Euclidean Error = 59.2083
# Epoch 19: Euclidean Error = 59.2081
# Epoch 20: Euclidean Error = 59.2080
# Epoch 21: Euclidean Error = 59.2081
# Early termination at epoch 21 due to negligible error change.
# Root Tip 3 failed to reach target within 200 epochs.
# Root Tip 4: Target Position: [7.61201542e+01 3.94784552e+01 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195      0.14160119 -0.06781045  0.12570603]
# Epoch 1: Euclidean Error = 85.6426
# Epoch 2: Euclidean Error = 85.6419
# Epoch 3: Euclidean Error = 85.6408
# Epoch 4: Euclidean Error = 85.6401
# Epoch 5: Euclidean Error = 85.6388
# Epoch 6: Euclidean Error = 85.6384
# Epoch 7: Euclidean Error = 85.6380
# Epoch 8: Euclidean Error = 85.6365
# Epoch 9: Euclidean Error = 85.6361
# Epoch 10: Euclidean Error = 85.6357
# Epoch 11: Euclidean Error = 85.6357
# Epoch 12: Euclidean Error = 85.6353
# INFO: Epoch: 13
# INFO: Current Position: X=0.0827, Y=0.0874, Z=0.1185
# INFO: Errors: X=76.0375, Y=39.3911, Z=0.0615
# INFO: Euclidean Error: 85.6350
# INFO: Epoch: 14
# INFO: Current Position: X=0.0830, Y=0.0874, Z=0.1184
# INFO: Errors: X=76.0372, Y=39.3911, Z=0.0614
# INFO: Euclidean Error: 85.6347
# INFO: Epoch: 15
# INFO: Current Position: X=0.0832, Y=0.0870, Z=0.1182
# INFO: Errors: X=76.0370, Y=39.3915, Z=0.0612
# INFO: Euclidean Error: 85.6347
# INFO: Epoch: 16
# INFO: Current Position: X=0.0831, Y=0.0865, Z=0.1182
# INFO: Errors: X=76.0371, Y=39.3920, Z=0.0612
# INFO: Euclidean Error: 85.6351
# INFO: Epoch: 17
# INFO: Current Position: X=0.0829, Y=0.0858, Z=0.1182
# INFO: Errors: X=76.0373, Y=39.3927, Z=0.0612
# INFO: Euclidean Error: 85.6356
# INFO: Epoch: 18
# INFO: Current Position: X=0.0842, Y=0.0864, Z=0.1183
# INFO: Errors: X=76.0360, Y=39.3921, Z=0.0613
# INFO: Euclidean Error: 85.6341
# INFO: Epoch: 19
# INFO: Current Position: X=0.0842, Y=0.0867, Z=0.1183
# INFO: Errors: X=76.0360, Y=39.3918, Z=0.0613
# INFO: Euclidean Error: 85.6340
# INFO: Epoch: 20
# INFO: Current Position: X=0.0847, Y=0.0868, Z=0.1183
# INFO: Errors: X=76.0355, Y=39.3917, Z=0.0613
# INFO: Euclidean Error: 85.6335
# INFO: Epoch: 21
# INFO: Current Position: X=0.0856, Y=0.0869, Z=0.1185
# INFO: Errors: X=76.0346, Y=39.3916, Z=0.0615
# INFO: Euclidean Error: 85.6327
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 4: Failed to reach target within 200 epochs.
# INFO: Root Tip 5: Target Position: [1.25864773e+02 4.50239427e+01 5.70000000e-02]
# INFO: Epoch: 1
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=125.7918, Y=44.9344, Z=0.0625
# INFO: Euclidean Error: 133.5765
# INFO: Epoch: 2
# INFO: Current Position: X=0.0733, Y=0.0892, Z=0.1194
# INFO: Errors: X=125.7915, Y=44.9347, Z=0.0624
# INFO: Euclidean Error: 133.5763
# INFO: Epoch: 3
# INFO: Current Position: X=0.0749, Y=0.0885, Z=0.1194
# INFO: Errors: X=125.7899, Y=44.9354, Z=0.0624
# INFO: Euclidean Error: 133.5750
# INFO: Epoch: 4
# INFO: Current Position: X=0.0750, Y=0.0880, Z=0.1194
# INFO: Errors: X=125.7898, Y=44.9359, Z=0.0624
# INFO: Euclidean Error: 133.5751
# INFO: Epoch: 5
# INFO: Current Position: X=0.0757, Y=0.0877, Z=0.1193
# INFO: Errors: X=125.7891, Y=44.9362, Z=0.0623
# INFO: Euclidean Error: 133.5746
# INFO: Epoch: 6
# INFO: Current Position: X=0.0763, Y=0.0877, Z=0.1193
# INFO: Errors: X=125.7885, Y=44.9362, Z=0.0623
# INFO: Euclidean Error: 133.5740
# INFO: Epoch: 7
# INFO: Current Position: X=0.0770, Y=0.0877, Z=0.1192
# INFO: Errors: X=125.7878, Y=44.9362, Z=0.0622
# INFO: Euclidean Error: 133.5733
# INFO: Epoch: 8
# Epoch 13: Euclidean Error = 85.6350
# Epoch 14: Euclidean Error = 85.6347
# Epoch 15: Euclidean Error = 85.6347
# Epoch 16: Euclidean Error = 85.6351
# Epoch 17: Euclidean Error = 85.6356
# Epoch 18: Euclidean Error = 85.6341
# Epoch 19: Euclidean Error = 85.6340
# Epoch 20: Euclidean Error = 85.6335
# Epoch 21: Euclidean Error = 85.6327
# Early termination at epoch 21 due to negligible error change.
# Root Tip 4 failed to reach target within 200 epochs.
# Root Tip 5: Target Position: [1.25864773e+02 4.50239427e+01 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195     -0.2214933  -0.03892605 -0.00483619]
# Epoch 1: Euclidean Error = 133.5765
# Epoch 2: Euclidean Error = 133.5763
# Epoch 3: Euclidean Error = 133.5750
# Epoch 4: Euclidean Error = 133.5751
# Epoch 5: Euclidean Error = 133.5746
# Epoch 6: Euclidean Error = 133.5740
# Epoch 7: Euclidean Error = 133.5733
# INFO: Current Position: X=0.0772, Y=0.0872, Z=0.1192
# INFO: Errors: X=125.7876, Y=44.9367, Z=0.0622
# INFO: Euclidean Error: 133.5733
# INFO: Epoch: 9
# INFO: Current Position: X=0.0785, Y=0.0873, Z=0.1192
# INFO: Errors: X=125.7863, Y=44.9366, Z=0.0622
# INFO: Euclidean Error: 133.5720
# INFO: Epoch: 10
# INFO: Current Position: X=0.0808, Y=0.0871, Z=0.1191
# INFO: Errors: X=125.7840, Y=44.9368, Z=0.0621
# INFO: Euclidean Error: 133.5700
# INFO: Epoch: 11
# INFO: Current Position: X=0.0817, Y=0.0868, Z=0.1191
# INFO: Errors: X=125.7831, Y=44.9371, Z=0.0621
# INFO: Euclidean Error: 133.5692
# INFO: Epoch: 12
# INFO: Current Position: X=0.0819, Y=0.0867, Z=0.1190
# INFO: Errors: X=125.7829, Y=44.9372, Z=0.0620
# INFO: Euclidean Error: 133.5690
# INFO: Epoch: 13
# INFO: Current Position: X=0.0821, Y=0.0866, Z=0.1190
# INFO: Errors: X=125.7827, Y=44.9373, Z=0.0620
# INFO: Euclidean Error: 133.5689
# INFO: Epoch: 14
# INFO: Current Position: X=0.0823, Y=0.0864, Z=0.1190
# INFO: Errors: X=125.7825, Y=44.9375, Z=0.0620
# INFO: Euclidean Error: 133.5688
# INFO: Epoch: 15
# INFO: Current Position: X=0.0828, Y=0.0863, Z=0.1189
# INFO: Errors: X=125.7820, Y=44.9376, Z=0.0619
# INFO: Euclidean Error: 133.5683
# INFO: Epoch: 16
# INFO: Current Position: X=0.0830, Y=0.0862, Z=0.1189
# INFO: Errors: X=125.7818, Y=44.9377, Z=0.0619
# INFO: Euclidean Error: 133.5682
# INFO: Epoch: 17
# INFO: Current Position: X=0.0833, Y=0.0862, Z=0.1190
# INFO: Errors: X=125.7815, Y=44.9377, Z=0.0620
# INFO: Euclidean Error: 133.5679
# INFO: Epoch: 18
# INFO: Current Position: X=0.0835, Y=0.0858, Z=0.1189
# INFO: Errors: X=125.7813, Y=44.9381, Z=0.0619
# INFO: Euclidean Error: 133.5678
# INFO: Epoch: 19
# INFO: Current Position: X=0.0840, Y=0.0853, Z=0.1189
# INFO: Errors: X=125.7808, Y=44.9386, Z=0.0619
# INFO: Euclidean Error: 133.5675
# INFO: Epoch: 20
# INFO: Current Position: X=0.0844, Y=0.0850, Z=0.1189
# INFO: Errors: X=125.7804, Y=44.9389, Z=0.0619
# INFO: Euclidean Error: 133.5673
# INFO: Epoch: 21
# INFO: Current Position: X=0.0847, Y=0.0848, Z=0.1189
# INFO: Errors: X=125.7801, Y=44.9391, Z=0.0619
# INFO: Euclidean Error: 133.5671
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 5: Failed to reach target within 200 epochs.
# INFO: Processing root tips for test_image_10.png
# INFO: Root Tip 1: Target Position: [1.46895942e+01 9.01801525e+01 5.70000000e-02]
# INFO: Epoch: 1
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=14.6166, Y=90.0907, Z=0.0625
# INFO: Euclidean Error: 91.2687
# INFO: Epoch: 2
# Epoch 8: Euclidean Error = 133.5733
# Epoch 9: Euclidean Error = 133.5720
# Epoch 10: Euclidean Error = 133.5700
# Epoch 11: Euclidean Error = 133.5692
# Epoch 12: Euclidean Error = 133.5690
# Epoch 13: Euclidean Error = 133.5689
# Epoch 14: Euclidean Error = 133.5688
# Epoch 15: Euclidean Error = 133.5683
# Epoch 16: Euclidean Error = 133.5682
# Epoch 17: Euclidean Error = 133.5679
# Epoch 18: Euclidean Error = 133.5678
# Epoch 19: Euclidean Error = 133.5675
# Epoch 20: Euclidean Error = 133.5673
# Epoch 21: Euclidean Error = 133.5671
# Early termination at epoch 21 due to negligible error change.
# Root Tip 5 failed to reach target within 200 epochs.
# Processing test_image_10.png...
# Root Tip 1: Target Position: [1.46895942e+01 9.01801525e+01 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195     -0.11007693  0.24044937  0.09150263]
# Epoch 1: Euclidean Error = 91.2687
# INFO: Current Position: X=0.0750, Y=0.0890, Z=0.1195
# INFO: Errors: X=14.6146, Y=90.0912, Z=0.0625
# INFO: Euclidean Error: 91.2689
# INFO: Epoch: 3
# INFO: Current Position: X=0.0771, Y=0.0885, Z=0.1194
# INFO: Errors: X=14.6125, Y=90.0917, Z=0.0624
# INFO: Euclidean Error: 91.2690
# INFO: Epoch: 4
# INFO: Errors: X=32.1415, Y=115.8240, Z=0.0617
# INFO: Euclidean Error: 120.2010
# INFO: Epoch: 12
# INFO: Current Position: X=0.0799, Y=0.0796, Z=0.1186
# INFO: Errors: X=32.1401, Y=115.8256, Z=0.0616
# INFO: Euclidean Error: 120.2021
# INFO: Epoch: 13
# Epoch 18: Euclidean Error = 91.2725
# Epoch 19: Euclidean Error = 91.2726
# Epoch 20: Euclidean Error = 91.2728
# Epoch 21: Euclidean Error = 91.2731
# Early termination at epoch 21 due to negligible error change.
# Root Tip 1 failed to reach target within 200 epochs.
# Root Tip 2: Target Position: [3.22199730e+01 1.15905179e+02 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195      0.10940373 -0.14963876  0.18989968]
# Epoch 1: Euclidean Error = 120.1944
# Epoch 2: Euclidean Error = 120.1948
# Epoch 3: Euclidean Error = 120.1956
# Epoch 4: Euclidean Error = 120.1963
# Epoch 5: Euclidean Error = 120.1967
# Epoch 6: Euclidean Error = 120.1973
# Epoch 7: Euclidean Error = 120.1977
# Epoch 8: Euclidean Error = 120.1983
# Epoch 9: Euclidean Error = 120.1990
# Epoch 10: Euclidean Error = 120.1999
# Epoch 11: Euclidean Error = 120.2010
# Epoch 12: Euclidean Error = 120.2021
# INFO: Current Position: X=0.0803, Y=0.0792, Z=0.1184
# INFO: Errors: X=32.1397, Y=115.8260, Z=0.0614
# INFO: Euclidean Error: 120.2024
# INFO: Epoch: 14
# INFO: Current Position: X=0.0809, Y=0.0795, Z=0.1182
# INFO: Errors: X=32.1391, Y=115.8257, Z=0.0612
# INFO: Euclidean Error: 120.2020
# INFO: Epoch: 15
# INFO: Current Position: X=0.0818, Y=0.0793, Z=0.1180
# INFO: Errors: X=32.1382, Y=115.8259, Z=0.0610
# INFO: Euclidean Error: 120.2019
# INFO: Epoch: 16
# INFO: Current Position: X=0.0822, Y=0.0792, Z=0.1177
# INFO: Errors: X=32.1378, Y=115.8260, Z=0.0607
# INFO: Euclidean Error: 120.2019
# INFO: Epoch: 17
# INFO: Current Position: X=0.0826, Y=0.0788, Z=0.1174
# INFO: Errors: X=32.1374, Y=115.8264, Z=0.0604
# INFO: Euclidean Error: 120.2022
# INFO: Epoch: 18
# INFO: Current Position: X=0.0826, Y=0.0786, Z=0.1171
# INFO: Errors: X=32.1374, Y=115.8266, Z=0.0601
# INFO: Euclidean Error: 120.2024
# INFO: Epoch: 19
# INFO: Current Position: X=0.0827, Y=0.0786, Z=0.1168
# INFO: Errors: X=32.1373, Y=115.8266, Z=0.0598
# INFO: Euclidean Error: 120.2023
# INFO: Epoch: 20
# INFO: Current Position: X=0.0827, Y=0.0784, Z=0.1164
# INFO: Errors: X=32.1373, Y=115.8268, Z=0.0594
# INFO: Euclidean Error: 120.2025
# INFO: Epoch: 21
# INFO: Current Position: X=0.0829, Y=0.0782, Z=0.1161
# INFO: Errors: X=32.1371, Y=115.8270, Z=0.0591
# INFO: Euclidean Error: 120.2027
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 2: Failed to reach target within 200 epochs.
# INFO: Root Tip 3: Target Position: [7.14622890e+01 1.06990034e+02 5.70000000e-02]
# INFO: Epoch: 1
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=71.3893, Y=106.9005, Z=0.0625
# INFO: Euclidean Error: 128.5463
# INFO: Epoch: 2
# INFO: Current Position: X=0.0731, Y=0.0888, Z=0.1196
# INFO: Errors: X=71.3892, Y=106.9012, Z=0.0626
# INFO: Euclidean Error: 128.5469
# INFO: Epoch: 3
# INFO: Current Position: X=0.0736, Y=0.0884, Z=0.1195
# INFO: Errors: X=71.3887, Y=106.9016, Z=0.0625
# INFO: Euclidean Error: 128.5469
# INFO: Epoch: 4
# INFO: Current Position: X=0.0742, Y=0.0880, Z=0.1195
# INFO: Errors: X=71.3881, Y=106.9020, Z=0.0625
# INFO: Euclidean Error: 128.5469
# INFO: Epoch: 5
# INFO: Current Position: X=0.0752, Y=0.0881, Z=0.1194
# INFO: Errors: X=71.3871, Y=106.9019, Z=0.0624
# INFO: Euclidean Error: 128.5463
# INFO: Epoch: 6
# INFO: Current Position: X=0.0757, Y=0.0880, Z=0.1193
# INFO: Errors: X=71.3866, Y=106.9020, Z=0.0623
# INFO: Euclidean Error: 128.5461
# INFO: Epoch: 7
# INFO: Current Position: X=0.0760, Y=0.0876, Z=0.1192
# INFO: Errors: X=71.3863, Y=106.9024, Z=0.0622
# INFO: Euclidean Error: 128.5462
# INFO: Epoch: 8
# INFO: Current Position: X=0.0762, Y=0.0870, Z=0.1189
# INFO: Errors: X=71.3861, Y=106.9030, Z=0.0619
# INFO: Euclidean Error: 128.5466
# INFO: Epoch: 9
# Epoch 13: Euclidean Error = 120.2024
# Epoch 14: Euclidean Error = 120.2020
# Epoch 15: Euclidean Error = 120.2019
# Epoch 16: Euclidean Error = 120.2019
# Epoch 17: Euclidean Error = 120.2022
# Epoch 18: Euclidean Error = 120.2024
# Epoch 19: Euclidean Error = 120.2023
# Epoch 20: Euclidean Error = 120.2025
# Epoch 21: Euclidean Error = 120.2027
# Early termination at epoch 21 due to negligible error change.
# Root Tip 2 failed to reach target within 200 epochs.
# Root Tip 3: Target Position: [7.14622890e+01 1.06990034e+02 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195     -0.22353521  0.0455853   0.1601719 ]
# Epoch 1: Euclidean Error = 128.5463
# Epoch 2: Euclidean Error = 128.5469
# Epoch 3: Euclidean Error = 128.5469
# Epoch 4: Euclidean Error = 128.5469
# Epoch 5: Euclidean Error = 128.5463
# Epoch 6: Euclidean Error = 128.5461
# Epoch 7: Euclidean Error = 128.5462
# Epoch 8: Euclidean Error = 128.5466
# INFO: Current Position: X=0.0770, Y=0.0866, Z=0.1186
# INFO: Errors: X=71.3853, Y=106.9034, Z=0.0616
# INFO: Euclidean Error: 128.5465
# INFO: Epoch: 10
# INFO: Current Position: X=0.0782, Y=0.0859, Z=0.1184
# INFO: Errors: X=71.3841, Y=106.9041, Z=0.0614
# INFO: Euclidean Error: 128.5464
# INFO: Epoch: 11
# INFO: Current Position: X=0.0791, Y=0.0851, Z=0.1180
# INFO: Errors: X=71.3832, Y=106.9049, Z=0.0610
# INFO: Euclidean Error: 128.5466
# INFO: Epoch: 12
# INFO: Current Position: X=0.0795, Y=0.0838, Z=0.1176
# INFO: Errors: X=71.3828, Y=106.9062, Z=0.0606
# INFO: Euclidean Error: 128.5475
# INFO: Epoch: 13
# INFO: Current Position: X=0.0801, Y=0.0832, Z=0.1172
# INFO: Errors: X=71.3822, Y=106.9068, Z=0.0602
# INFO: Euclidean Error: 128.5476
# INFO: Epoch: 14
# INFO: Current Position: X=0.0807, Y=0.0821, Z=0.1167
# INFO: Errors: X=71.3816, Y=106.9079, Z=0.0597
# INFO: Euclidean Error: 128.5482
# INFO: Epoch: 15
# INFO: Current Position: X=0.0810, Y=0.0811, Z=0.1163
# INFO: Errors: X=71.3813, Y=106.9089, Z=0.0593
# INFO: Euclidean Error: 128.5489
# INFO: Epoch: 16
# INFO: Current Position: X=0.0815, Y=0.0799, Z=0.1157
# INFO: Errors: X=71.3808, Y=106.9101, Z=0.0587
# INFO: Euclidean Error: 128.5496
# INFO: Epoch: 17
# INFO: Current Position: X=0.0819, Y=0.0783, Z=0.1152
# INFO: Errors: X=71.3804, Y=106.9117, Z=0.0582
# INFO: Euclidean Error: 128.5507
# INFO: Epoch: 18
# INFO: Current Position: X=0.0823, Y=0.0762, Z=0.1152
# INFO: Errors: X=71.3800, Y=106.9138, Z=0.0582
# INFO: Euclidean Error: 128.5522
# INFO: Epoch: 19
# INFO: Current Position: X=0.0826, Y=0.0755, Z=0.1146
# INFO: Errors: X=71.3797, Y=106.9145, Z=0.0576
# INFO: Euclidean Error: 128.5526
# INFO: Epoch: 20
# INFO: Current Position: X=0.0840, Y=0.0743, Z=0.1154
# INFO: Errors: X=71.3783, Y=106.9157, Z=0.0584
# INFO: Euclidean Error: 128.5529
# INFO: Epoch: 21
# INFO: Current Position: X=0.0839, Y=0.0727, Z=0.1149
# INFO: Errors: X=71.3784, Y=106.9173, Z=0.0579
# INFO: Euclidean Error: 128.5542
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 3: Failed to reach target within 200 epochs.
# INFO: Root Tip 4: Target Position: [1.07756070e+02 9.66785414e+01 5.70000000e-02]
# INFO: Epoch: 1
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=107.6831, Y=96.5890, Z=0.0625
# INFO: Euclidean Error: 144.6551
# INFO: Epoch: 2
# INFO: Current Position: X=0.0737, Y=0.0894, Z=0.1195
# INFO: Errors: X=107.6824, Y=96.5891, Z=0.0625
# INFO: Euclidean Error: 144.6546
# INFO: Epoch: 3
# INFO: Current Position: X=0.0742, Y=0.0890, Z=0.1194
# INFO: Errors: X=107.6819, Y=96.5895, Z=0.0624
# INFO: Euclidean Error: 144.6545
# INFO: Epoch: 4
# INFO: Current Position: X=0.0744, Y=0.0886, Z=0.1193
# INFO: Errors: X=107.6817, Y=96.5899, Z=0.0623
# INFO: Euclidean Error: 144.6546
# INFO: Epoch: 5
# INFO: Current Position: X=0.0748, Y=0.0880, Z=0.1192
# INFO: Errors: X=107.6813, Y=96.5905, Z=0.0622
# INFO: Euclidean Error: 144.6547
# Epoch 9: Euclidean Error = 128.5465
# Epoch 10: Euclidean Error = 128.5464
# Epoch 11: Euclidean Error = 128.5466
# Epoch 12: Euclidean Error = 128.5475
# Epoch 13: Euclidean Error = 128.5476
# Epoch 14: Euclidean Error = 128.5482
# Epoch 15: Euclidean Error = 128.5489
# Epoch 16: Euclidean Error = 128.5496
# Epoch 17: Euclidean Error = 128.5507
# Epoch 18: Euclidean Error = 128.5522
# Epoch 19: Euclidean Error = 128.5526
# Epoch 20: Euclidean Error = 128.5529
# Epoch 21: Euclidean Error = 128.5542
# Early termination at epoch 21 due to negligible error change.
# Root Tip 3 failed to reach target within 200 epochs.
# Root Tip 4: Target Position: [1.07756070e+02 9.66785414e+01 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1
# INFO: Current Position: X=0.0808, Y=0.0844, Z=0.1168
# INFO: Errors: X=107.6753, Y=96.5941, Z=0.0598
# INFO: Euclidean Error: 144.6527
# INFO: Epoch: 20
# INFO: Current Position: X=0.0806, Y=0.0843, Z=0.1164
# INFO: Errors: X=107.6755, Y=96.5942, Z=0.0594
# INFO: Euclidean Error: 144.6529
# INFO: Epoch: 21
# INFO: Current Position: X=0.0804, Y=0.0842, Z=0.1160
# INFO: Errors: X=107.6757, Y=96.5943, Z=0.0590
# INFO: Euclidean Error: 144.6531
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 4: Failed to reach target within 200 epochs.
# INFO: Root Tip 5: Target Position: [1.35525906e+02 8.86763931e+01 5.70000000e-02]
# INFO: Epoch: 1
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=135.4529, Y=88.5869, Z=0.0625
# INFO: Euclidean Error: 161.8491
# INFO: Epoch: 2
# INFO: Current Position: X=0.0735, Y=0.0892, Z=0.1195
# INFO: Errors: X=135.4524, Y=88.5872, Z=0.0625
# INFO: Euclidean Error: 161.8488
# INFO: Epoch: 3
# INFO: Current Position: X=0.0758, Y=0.0884, Z=0.1195
# INFO: Errors: X=135.4501, Y=88.5880, Z=0.0625
# INFO: Euclidean Error: 161.8474
# INFO: Epoch: 4
# Epoch 6: Euclidean Error = 144.6546
# Epoch 7: Euclidean Error = 144.6547
# Epoch 8: Euclidean Error = 144.6546
# Epoch 9: Euclidean Error = 144.6547
# Epoch 10: Euclidean Error = 144.6537
# Epoch 11: Euclidean Error = 144.6535
# Epoch 12: Euclidean Error = 144.6530
# Epoch 13: Euclidean Error = 144.6529
# Epoch 14: Euclidean Error = 144.6526
# Epoch 15: Euclidean Error = 144.6526
# Epoch 16: Euclidean Error = 144.6526
# Epoch 17: Euclidean Error = 144.6527
# Epoch 18: Euclidean Error = 144.6527
# Epoch 19: Euclidean Error = 144.6527
# Epoch 20: Euclidean Error = 144.6529
# Epoch 21: Euclidean Error = 144.6531
# Early termination at epoch 21 due to negligible error change.
# Root Tip 4 failed to reach target within 200 epochs.
# Root Tip 5: Target Position: [1.35525906e+02 8.86763931e+01 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195      0.1882276  -0.21563779  0.2723907 ]
# Epoch 1: Euclidean Error = 161.8491
# Epoch 2: Euclidean Error = 161.8488
# Epoch 3: Euclidean Error = 161.8474
# INFO: Current Position: X=0.0766, Y=0.0878, Z=0.1194
# INFO: Errors: X=135.4493, Y=88.5886, Z=0.0624
# INFO: Euclidean Error: 161.8470
# INFO: Epoch: 5
# INFO: Current Position: X=0.0773, Y=0.0874, Z=0.1192
# INFO: Errors: X=135.4486, Y=88.5890, Z=0.0622
# INFO: Euclidean Error: 161.8467
# INFO: Epoch: 6
# INFO: Current Position: X=0.0778, Y=0.0871, Z=0.1189
# INFO: Errors: X=135.4481, Y=88.5893, Z=0.0619
# INFO: Euclidean Error: 161.8464
# INFO: Epoch: 7
# INFO: Current Position: X=0.0780, Y=0.0869, Z=0.1186
# INFO: Errors: X=135.4479, Y=88.5895, Z=0.0616
# INFO: Euclidean Error: 161.8463
# INFO: Epoch: 8
# INFO: Current Position: X=0.0784, Y=0.0864, Z=0.1183
# INFO: Errors: X=135.4475, Y=88.5900, Z=0.0613
# INFO: Euclidean Error: 161.8463
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195      0.16860303  0.27233627 -0.01653828]
# Epoch 1: Euclidean Error = 105.4318
# Epoch 2: Euclidean Error = 105.4324
# Epoch 3: Euclidean Error = 105.4333
# Epoch 4: Euclidean Error = 105.4343
# Epoch 5: Euclidean Error = 105.4350
# Epoch 6: Euclidean Error = 105.4359
# Epoch 7: Euclidean Error = 105.4365
# Epoch 8: Euclidean Error = 105.4372
# Epoch 9: Euclidean Error = 105.4381
# Epoch 10: Euclidean Error = 105.4391
# Epoch 11: Euclidean Error = 105.4393
# Epoch 12: Euclidean Error = 105.4395
# Epoch 13: Euclidean Error = 105.4388
# Epoch 14: Euclidean Error = 105.4388
# Epoch 15: Euclidean Error = 105.4390
# INFO: Current Position: X=0.0770, Y=0.0821, Z=0.1186
# INFO: Errors: X=4.3211, Y=105.3505, Z=0.0616
# INFO: Euclidean Error: 105.4391
# INFO: Epoch: 17
# INFO: Current Position: X=0.0773, Y=0.0820, Z=0.1185
# INFO: Errors: X=4.3208, Y=105.3506, Z=0.0615
# INFO: Euclidean Error: 105.4392
# INFO: Epoch: 18
# INFO: Current Position: X=0.0774, Y=0.0819, Z=0.1184
# INFO: Errors: X=4.3207, Y=105.3507, Z=0.0614
# INFO: Euclidean Error: 105.4392
# INFO: Epoch: 19
# INFO: Current Position: X=0.0775, Y=0.0814, Z=0.1183
# INFO: Errors: X=4.3206, Y=105.3512, Z=0.0613
# INFO: Euclidean Error: 105.4397
# INFO: Epoch: 20
# INFO: Current Position: X=0.0775, Y=0.0810, Z=0.1182
# INFO: Errors: X=4.3206, Y=105.3516, Z=0.0612
# INFO: Euclidean Error: 105.4401
# INFO: Epoch: 21
# INFO: Current Position: X=0.0773, Y=0.0807, Z=0.1181
# INFO: Errors: X=4.3208, Y=105.3519, Z=0.0611
# INFO: Euclidean Error: 105.4405
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 1: Failed to reach target within 200 epochs.
# INFO: Root Tip 2: Target Position: [3.4591125e+01 1.1128649e+02 5.7000000e-02]
# INFO: Epoch: 1
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=34.5181, Y=111.1970, Z=0.0625
# INFO: Euclidean Error: 116.4314
# INFO: Epoch: 2
# INFO: Current Position: X=0.0734, Y=0.0885, Z=0.1195
# INFO: Errors: X=34.5177, Y=111.1980, Z=0.0625
# INFO: Euclidean Error: 116.4323
# ...
# INFO: Errors: X=47.5316, Y=55.2964, Z=0.0624
# INFO: Euclidean Error: 72.9174
# INFO: Epoch: 12
# INFO: Current Position: X=0.0747, Y=0.0825, Z=0.1193
# INFO: Errors: X=47.5313, Y=55.2964, Z=0.0623
# INFO: Euclidean Error: 72.9172
# INFO: Epoch: 13
# INFO: Current Position: X=0.0749, Y=0.0824, Z=0.1192
# INFO: Errors: X=47.5311, Y=55.2965, Z=0.0622
# INFO: Euclidean Error: 72.9171
# INFO: Epoch: 14
# INFO: Current Position: X=0.0750, Y=0.0819, Z=0.1192
# INFO: Errors: X=47.5310, Y=55.2970, Z=0.0622
# INFO: Euclidean Error: 72.9174
# INFO: Epoch: 15
# INFO: Current Position: X=0.0751, Y=0.0818, Z=0.1191
# INFO: Errors: X=47.5309, Y=55.2971, Z=0.0621
# INFO: Euclidean Error: 72.9174
# INFO: Epoch: 16
# INFO: Current Position: X=0.0750, Y=0.0818, Z=0.1191
# INFO: Errors: X=47.5310, Y=55.2971, Z=0.0621
# INFO: Euclidean Error: 72.9175
# INFO: Epoch: 17
# INFO: Current Position: X=0.0749, Y=0.0818, Z=0.1190
# INFO: Errors: X=47.5311, Y=55.2971, Z=0.0620
# INFO: Euclidean Error: 72.9176
# Epoch 41: Euclidean Error = 62.6984
# Early termination at epoch 41 due to negligible error change.
# Root Tip 1 failed to reach target within 200 epochs.
# Root Tip 2: Target Position: [47.60596301 55.37886359  0.057     ]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195     -0.11616639 -0.26258346  0.2976968 ]
# Epoch 1: Euclidean Error = 72.9130
# Epoch 2: Euclidean Error = 72.9130
# Epoch 3: Euclidean Error = 72.9135
# Epoch 4: Euclidean Error = 72.9140
# Epoch 5: Euclidean Error = 72.9149
# Epoch 6: Euclidean Error = 72.9150
# Epoch 7: Euclidean Error = 72.9155
# Epoch 8: Euclidean Error = 72.9165
# Epoch 9: Euclidean Error = 72.9172
# Epoch 10: Euclidean Error = 72.9179
# Epoch 11: Euclidean Error = 72.9174
# Epoch 12: Euclidean Error = 72.9172
# Epoch 13: Euclidean Error = 72.9171
# Epoch 14: Euclidean Error = 72.9174
# Epoch 15: Euclidean Error = 72.9174
# Epoch 16: Euclidean Error = 72.9175
# Epoch 17: Euclidean Error = 72.9176
# INFO: Epoch: 18
# INFO: Current Position: X=0.0745, Y=0.0820, Z=0.1190
# INFO: Errors: X=47.5315, Y=55.2969, Z=0.0620
# INFO: Euclidean Error: 72.9177
# INFO: Epoch: 19
# INFO: Current Position: X=0.0745, Y=0.0818, Z=0.1189
# INFO: Errors: X=47.5315, Y=55.2971, Z=0.0619
# INFO: Euclidean Error: 72.9178
# INFO: Epoch: 20
# INFO: Current Position: X=0.0747, Y=0.0814, Z=0.1189
# INFO: Errors: X=47.5313, Y=55.2975, Z=0.0619
# INFO: Euclidean Error: 72.9180
# INFO: Epoch: 21
# INFO: Current Position: X=0.0750, Y=0.0806, Z=0.1188
# INFO: Errors: X=47.5310, Y=55.2983, Z=0.0618
# INFO: Euclidean Error: 72.9184
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 2: Failed to reach target within 200 epochs.
# INFO: Root Tip 3: Target Position: [7.55902375e+01 6.20920752e+01 5.70000000e-02]
# INFO: Epoch: 1
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=75.5172, Y=62.0026, Z=0.0625
# INFO: Euclidean Error: 97.7097
# INFO: Epoch: 2
# INFO: Current Position: X=0.0731, Y=0.0892, Z=0.1195
# INFO: Errors: X=75.5171, Y=62.0029, Z=0.0625
# INFO: Euclidean Error: 97.7098
# INFO: Epoch: 3
# INFO: Current Position: X=0.0732, Y=0.0885, Z=0.1195
# INFO: Errors: X=75.5170, Y=62.0036, Z=0.0625
# INFO: Euclidean Error: 97.7101
# INFO: Epoch: 4
# INFO: Current Position: X=0.0734, Y=0.0871, Z=0.1195
# INFO: Errors: X=75.5168, Y=62.0050, Z=0.0625
# INFO: Euclidean Error: 97.7109
# INFO: Epoch: 5
# INFO: Current Position: X=0.0735, Y=0.0871, Z=0.1194
# INFO: Errors: X=75.5167, Y=62.0050, Z=0.0624
# INFO: Euclidean Error: 97.7108
# INFO: Epoch: 6
# INFO: Current Position: X=0.0733, Y=0.0865, Z=0.1193
# INFO: Errors: X=75.5169, Y=62.0056, Z=0.0623
# INFO: Euclidean Error: 97.7113
# INFO: Epoch: 7
# INFO: Current Position: X=0.0733, Y=0.0862, Z=0.1192
# INFO: Errors: X=75.5169, Y=62.0059, Z=0.0622
# INFO: Euclidean Error: 97.7115
# INFO: Epoch: 8
# INFO: Current Position: X=0.0729, Y=0.0858, Z=0.1191
# INFO: Errors: X=75.5173, Y=62.0063, Z=0.0621
# INFO: Euclidean Error: 97.7121
# INFO: Epoch: 9
# INFO: Current Position: X=0.0726, Y=0.0855, Z=0.1190
# INFO: Errors: X=75.5176, Y=62.0066, Z=0.0620
# INFO: Euclidean Error: 97.7125
# INFO: Epoch: 10
# INFO: Current Position: X=0.0727, Y=0.0846, Z=0.1190
# INFO: Errors: X=75.5175, Y=62.0075, Z=0.0620
# INFO: Euclidean Error: 97.7130
# INFO: Epoch: 11
# INFO: Current Position: X=0.0728, Y=0.0839, Z=0.1189
# INFO: Errors: X=75.5174, Y=62.0082, Z=0.0619
# INFO: Euclidean Error: 97.7134
# INFO: Epoch: 12
# INFO: Current Position: X=0.0730, Y=0.0832, Z=0.1188
# INFO: Errors: X=75.5172, Y=62.0089, Z=0.0618
# INFO: Euclidean Error: 97.7137
# INFO: Epoch: 13
# INFO: Current Position: X=0.0731, Y=0.0826, Z=0.1187
# INFO: Errors: X=75.5171, Y=62.0095, Z=0.0617
# INFO: Euclidean Error: 97.7140
# INFO: Epoch: 14
# INFO: Current Position: X=0.0733, Y=0.0816, Z=0.1185
# INFO: Errors: X=75.5169, Y=62.0105, Z=0.0615
# INFO: Euclidean Error: 97.7144
# INFO: Epoch: 15
# INFO: Current Position: X=0.0735, Y=0.0805, Z=0.1184
# INFO: Errors: X=75.5167, Y=62.0116, Z=0.0614
# INFO: Euclidean Error: 97.7150
# Epoch 18: Euclidean Error = 72.9177
# Epoch 19: Euclidean Error = 72.9178
# Epoch 20: Euclidean Error = 72.9180
# Epoch 21: Euclidean Error = 72.9184
# Early termination at epoch 21 due to negligible error change.
# Root Tip 2 failed to reach target within 200 epochs.
# Root Tip 3: Target Position: [7.55902375e+01 6.20920752e+01 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195     -0.0056362   0.15641525  0.12470712]
# Epoch 1: Euclidean Error = 97.7097
# Epoch 2: Euclidean Error = 97.7098
# Epoch 3: Euclidean Error = 97.7101
# Epoch 4: Euclidean Error = 97.7109
# Epoch 5: Euclidean Error = 97.7108
# Epoch 6: Euclidean Error = 97.7113
# Epoch 7: Euclidean Error = 97.7115
# Epoch 8: Euclidean Error = 97.7121
# Epoch 9: Euclidean Error = 97.7125
# Epoch 10: Euclidean Error = 97.7130
# Epoch 11: Euclidean Error = 97.7134
# INFO: Current Position: X=0.0731, Y=0.0789, Z=0.1194
# INFO: Errors: X=106.0211, Y=50.8424, Z=0.0624
# INFO: Euclidean Error: 117.5815
# INFO: Epoch: 11
# INFO: Current Position: X=0.0732, Y=0.0770, Z=0.1194
# INFO: Errors: X=106.0210, Y=50.8443, Z=0.0624
# INFO: Euclidean Error: 117.5823
# INFO: Epoch: 12
# INFO: Current Position: X=0.0733, Y=0.0755, Z=0.1193
# INFO: Errors: X=106.0209, Y=50.8458, Z=0.0623
# INFO: Euclidean Error: 117.5828
# INFO: Epoch: 13
# INFO: Current Position: X=0.0734, Y=0.0734, Z=0.1193
# INFO: Errors: X=106.0208, Y=50.8479, Z=0.0623
# INFO: Euclidean Error: 117.5837
# Epoch 16: Euclidean Error = 97.7155
# Epoch 17: Euclidean Error = 97.7161
# Epoch 18: Euclidean Error = 97.7162
# Epoch 19: Euclidean Error = 97.7165
# Epoch 20: Euclidean Error = 97.7167
# Epoch 21: Euclidean Error = 97.7167
# Early termination at epoch 21 due to negligible error change.
# Root Tip 3 failed to reach target within 200 epochs.
# Root Tip 4: Target Position: [1.06094169e+02 5.09212911e+01 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195     -0.05303539 -0.18106559 -0.24969417]
# Epoch 1: Euclidean Error = 117.5771
# Epoch 2: Euclidean Error = 117.5771
# Epoch 3: Euclidean Error = 117.5773
# Epoch 4: Euclidean Error = 117.5769
# Epoch 5: Euclidean Error = 117.5772
# Epoch 6: Euclidean Error = 117.5780
# Epoch 7: Euclidean Error = 117.5786
# Epoch 8: Euclidean Error = 117.5796
# Epoch 9: Euclidean Error = 117.5804
# Epoch 10: Euclidean Error = 117.5815
# Epoch 11: Euclidean Error = 117.5823
# Epoch 12: Euclidean Error = 117.5828
# Epoch 13: Euclidean Error = 117.5837
# INFO: Epoch: 14
# INFO: Current Position: X=0.0734, Y=0.0728, Z=0.1193
# INFO: Errors: X=106.0208, Y=50.8485, Z=0.0623
# INFO: Euclidean Error: 117.5839
# INFO: Epoch: 15
# INFO: Current Position: X=0.0735, Y=0.0715, Z=0.1193
# INFO: Errors: X=106.0207, Y=50.8498, Z=0.0623
# INFO: Euclidean Error: 117.5844
# INFO: Epoch: 16
# INFO: Current Position: X=0.0734, Y=0.0715, Z=0.1193
# INFO: Errors: X=106.0208, Y=50.8498, Z=0.0623
# INFO: Euclidean Error: 117.5845
# INFO: Epoch: 17
# INFO: Current Position: X=0.0736, Y=0.0710, Z=0.1192
# INFO: Errors: X=106.0206, Y=50.8503, Z=0.0622
# INFO: Euclidean Error: 117.5845
# INFO: Epoch: 18
# INFO: Current Position: X=0.0735, Y=0.0712, Z=0.1192
# INFO: Errors: X=106.0207, Y=50.8501, Z=0.0622
# INFO: Euclidean Error: 117.5845
# INFO: Epoch: 19
# INFO: Current Position: X=0.0734, Y=0.0713, Z=0.1192
# INFO: Errors: X=106.0208, Y=50.8500, Z=0.0622
# INFO: Euclidean Error: 117.5846
# INFO: Epoch: 20
# INFO: Current Position: X=0.0734, Y=0.0712, Z=0.1193
# INFO: Errors: X=106.0208, Y=50.8501, Z=0.0623
# INFO: Euclidean Error: 117.5846
# INFO: Epoch: 21
# INFO: Current Position: X=0.0734, Y=0.0711, Z=0.1193
# INFO: Errors: X=106.0208, Y=50.8502, Z=0.0623
# INFO: Euclidean Error: 117.5846
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 4: Failed to reach target within 200 epochs.
# INFO: Root Tip 5: Target Position: [1.31934055e+02 6.07494329e+01 5.70000000e-02]
# INFO: Epoch: 1
# INFO: Current Position: X=0.0730, Y=0.0895, Z=0.1195
# INFO: Errors: X=131.8611, Y=60.6599, Z=0.0625
# INFO: Euclidean Error: 145.1446
# INFO: Epoch: 2
# INFO: Current Position: X=0.0732, Y=0.0894, Z=0.1195
# INFO: Errors: X=131.8609, Y=60.6600, Z=0.0625
# INFO: Euclidean Error: 145.1445
# INFO: Epoch: 3
# INFO: Current Position: X=0.0730, Y=0.0892, Z=0.1195
# INFO: Errors: X=131.8611, Y=60.6602, Z=0.0625
# INFO: Euclidean Error: 145.1448
# INFO: Epoch: 4
# INFO: Current Position: X=0.0730, Y=0.0889, Z=0.1195
# INFO: Errors: X=131.8611, Y=60.6605, Z=0.0625
# INFO: Euclidean Error: 145.1449
# INFO: Epoch: 5
# INFO: Current Position: X=0.0728, Y=0.0889, Z=0.1194
# INFO: Errors: X=131.8613, Y=60.6605, Z=0.0624
# INFO: Euclidean Error: 145.1451
# INFO: Epoch: 6
# INFO: Current Position: X=0.0730, Y=0.0887, Z=0.1193
# INFO: Errors: X=131.8611, Y=60.6607, Z=0.0623
# INFO: Euclidean Error: 145.1450
# INFO: Epoch: 7
# INFO: Current Position: X=0.0731, Y=0.0884, Z=0.1192
# INFO: Errors: X=131.8610, Y=60.6610, Z=0.0622
# INFO: Euclidean Error: 145.1450
# INFO: Epoch: 8
# INFO: Current Position: X=0.0733, Y=0.0885, Z=0.1191
# INFO: Errors: X=131.8608, Y=60.6609, Z=0.0621
# INFO: Euclidean Error: 145.1448
# INFO: Epoch: 9
# INFO: Current Position: X=0.0734, Y=0.0884, Z=0.1189
# INFO: Errors: X=131.8607, Y=60.6610, Z=0.0619
# INFO: Euclidean Error: 145.1447
# INFO: Epoch: 10
# INFO: Current Position: X=0.0736, Y=0.0883, Z=0.1188
# INFO: Errors: X=131.8605, Y=60.6611, Z=0.0618
# INFO: Euclidean Error: 145.1446
# INFO: Epoch: 11
# INFO: Current Position: X=0.0735, Y=0.0882, Z=0.1186
# INFO: Errors: X=131.8606, Y=60.6612, Z=0.0616
# INFO: Euclidean Error: 145.1447
# INFO: Epoch: 12
# INFO: Current Position: X=0.0737, Y=0.0880, Z=0.1184
# Epoch 14: Euclidean Error = 117.5839
# Epoch 15: Euclidean Error = 117.5844
# Epoch 16: Euclidean Error = 117.5845
# Epoch 17: Euclidean Error = 117.5845
# Epoch 18: Euclidean Error = 117.5845
# Epoch 19: Euclidean Error = 117.5846
# Epoch 20: Euclidean Error = 117.5846
# Epoch 21: Euclidean Error = 117.5846
# Early termination at epoch 21 due to negligible error change.
# Root Tip 4 failed to reach target within 200 epochs.
# Root Tip 5: Target Position: [1.31934055e+02 6.07494329e+01 5.70000000e-02]
# Environment reset. Initial observation: [ 0.073       0.0895      0.1195     -0.22226085 -0.16845234 -0.18983376]
# Epoch 1: Euclidean Error = 145.1446
# Epoch 2: Euclidean Error = 145.1445
# Epoch 3: Euclidean Error = 145.1448
# Epoch 4: Euclidean Error = 145.1449
# Epoch 5: Euclidean Error = 145.1451
# Epoch 6: Euclidean Error = 145.1450
# Epoch 7: Euclidean Error = 145.1450
# Epoch 8: Euclidean Error = 145.1448
# Epoch 9: Euclidean Error = 145.1447
# Epoch 10: Euclidean Error = 145.1446
# Epoch 11: Euclidean Error = 145.1447
# INFO: Errors: X=131.8604, Y=60.6614, Z=0.0614
# INFO: Euclidean Error: 145.1446
# INFO: Epoch: 13
# INFO: Current Position: X=0.0740, Y=0.0882, Z=0.1183
# INFO: Errors: X=131.8601, Y=60.6612, Z=0.0613
# INFO: Euclidean Error: 145.1443
# INFO: Epoch: 14
# INFO: Current Position: X=0.0742, Y=0.0879, Z=0.1182
# INFO: Errors: X=131.8599, Y=60.6615, Z=0.0612
# INFO: Euclidean Error: 145.1442
# INFO: Epoch: 15
# INFO: Current Position: X=0.0745, Y=0.0879, Z=0.1181
# INFO: Errors: X=131.8596, Y=60.6615, Z=0.0611
# INFO: Euclidean Error: 145.1440
# INFO: Epoch: 16
# INFO: Current Position: X=0.0751, Y=0.0882, Z=0.1179
# INFO: Errors: X=131.8590, Y=60.6612, Z=0.0609
# INFO: Euclidean Error: 145.1433
# INFO: Epoch: 17
# INFO: Current Position: X=0.0756, Y=0.0887, Z=0.1178
# INFO: Errors: X=131.8585, Y=60.6607, Z=0.0608
# INFO: Euclidean Error: 145.1426
# INFO: Epoch: 18
# INFO: Current Position: X=0.0762, Y=0.0885, Z=0.1177
# INFO: Errors: X=131.8579, Y=60.6609, Z=0.0607
# INFO: Euclidean Error: 145.1422
# INFO: Epoch: 19
# INFO: Current Position: X=0.0768, Y=0.0889, Z=0.1175
# INFO: Errors: X=131.8573, Y=60.6605, Z=0.0605
# INFO: Euclidean Error: 145.1414
# INFO: Epoch: 20
# INFO: Current Position: X=0.0774, Y=0.0892, Z=0.1174
# INFO: Errors: X=131.8567, Y=60.6602, Z=0.0604
# INFO: Euclidean Error: 145.1408
# INFO: Epoch: 21
# INFO: Current Position: X=0.0775, Y=0.0893, Z=0.1173
# INFO: Errors: X=131.8566, Y=60.6601, Z=0.0603
# INFO: Euclidean Error: 145.1406
# INFO: Terminating early due to negligible error change after 21 epochs.
# WARNING: Root Tip 5: Failed to reach target within 200 epochs.
# INFO: PID Controller Test Complete.
# Epoch 12: Euclidean Error = 145.1446
# Epoch 13: Euclidean Error = 145.1443
# Epoch 14: Euclidean Error = 145.1442
# Epoch 15: Euclidean Error = 145.1440
# Epoch 16: Euclidean Error = 145.1433
# Epoch 17: Euclidean Error = 145.1426
# Epoch 18: Euclidean Error = 145.1422
# Epoch 19: Euclidean Error = 145.1414
# Epoch 20: Euclidean Error = 145.1408
# Epoch 21: Euclidean Error = 145.1406
# Early termination at epoch 21 due to negligible error change.
# Root Tip 5 failed to reach target within 200 epochs.
# PID Controller Test Complete. Check the log file for details.
